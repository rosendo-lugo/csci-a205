# %%
import re

class SpamWordsReader:
    def __init__(self, file_path):
        self.file_path = file_path
        self.spam_words = self.read_spam_keywords()

    def read_spam_keywords(self):
        with open(self.file_path, 'r') as file:
            # Using a set for faster lookups
            return set(line.strip().lower() for line in file if line.strip())

class Email:
    def __init__(self, content):
        self.content = content
        self.cleaned_content = self.preprocess_content()

    def preprocess_content(self):
        content = self.content.lower()
        # Improved regex to handle punctuation and split phrases
        content = re.sub(r'[^a-z0-9\s]', ' ', content)
        return content

class SpamDetector:
    def __init__(self, spam_words):
        self.spam_words = spam_words

    def calculate_spam_score(self, email):
        words = email.split()
        print(words)
        # Counting each occurrence of spam words
        spam_count = sum(any(spam_word in word for spam_word in self.spam_words) for word in words)
        # Filtering out stop words for ham count
        stop_words = {'a', 'by', 'the', 'of', 'and', 'in', 'on', 'for', 'with'}
        ham_count = sum(word not in stop_words for word in words)
        return spam_count, ham_count

    def evaluate_spam_likelihood(self, spam_score, ham_score):
        if ham_score == 0:
            return "Unable to determine (no ham words)"
        ratio = spam_score / ham_score
        if ratio > 0.4:
            return "Highly likely to be spam"
        elif ratio > 0.2:
            return "Possibly spam"
        else:
            return "Unlikely to be spam"

if __name__ == "__main__":
    # Assuming spam_words.txt is in the same directory as this script
    spam_reader = SpamWordsReader("spam_words.txt")
    
    while True:
        email_content = input("\nEnter the email content (or type 'exit' to quit):\n")
        if email_content.lower() == 'exit':
            break

        email = Email(email_content)
        detector = SpamDetector(spam_reader.spam_words)
        spam_score, ham_score = detector.calculate_spam_score(email.cleaned_content)
        likelihood = detector.evaluate_spam_likelihood(spam_score, ham_score)

        print(f"\nSpam Score: {spam_score}")
        print(f"Ham Score: {ham_score}")
        print(f"Likelihood of Spam: {likelihood}")

# %% [markdown]
# Urgent! \nPlease verify your bank account by
#     clicking the link: ACTION REQUIRED. Please verify your
#     Bank of America account information to avoid a hold on
#     your account. Click here to confirm: [Link]

# %%
import re

class SpamWordsReader:
    def __init__(self, file_path):
        self.file_path = file_path
        self.spam_words = self.read_spam_keywords()

    def read_spam_keywords(self):
        with open(self.file_path, 'r') as file:
            # Using a set for faster lookups
            return set(line.strip().lower() for line in file if line.strip())

class Email:
    def __init__(self, content):
        self.content = content
        self.cleaned_content = self.preprocess_content()

    def preprocess_content(self):
        content = self.content.lower()
        # Improved regex to handle punctuation and split phrases
        content = re.sub(r'[^a-z0-9\'w\s]', ' ', content)
        return content

class SpamDetector:
    def __init__(self, spam_words):
        self.spam_words = spam_words

    def calculate_spam_score(self, email):
        # Normalizing email content for comparison
        normalized_email = ' ' + email + ' '  # Add spaces to match phrases at the start or end
        print(normalized_email)  # Corrected typo here
        # Counting each occurrence of spam phrases
        spam_count = sum(normalized_email.count(' ' + spam_word + ' ') for spam_word in self.spam_words)
        # print(f'SPAMMMM: {spam_word}')
        # Filtering out stop words for ham count
        stop_words = {'a', 'by', 'the', 'of', 'and', 'in', 'on', 'for', 'with'}
        words = email.split()
        ham_count = sum(word not in stop_words for word in words)
        return spam_count, ham_count


    def evaluate_spam_likelihood(self, spam_score, ham_score):
        if ham_score == 0:
            return "Unable to determine (no ham words)"
        ratio = spam_score / ham_score
        if ratio > 0.4:
            return "Highly likely to be spam"
        elif ratio > 0.2:
            return "Possibly spam"
        else:
            return "Unlikely to be spam"

if __name__ == "__main__":
    # Assuming spam_words.txt is in the same directory as this script
    spam_reader = SpamWordsReader("spam_words.txt")
    
    while True:
        email_content = input("\nEnter the email content (or type 'exit' to quit):\n")
        if email_content.lower() == 'exit':
            break

        email = Email(email_content)
        detector = SpamDetector(spam_reader.spam_words)
        spam_score, ham_score = detector.calculate_spam_score(email.cleaned_content)
        likelihood = detector.evaluate_spam_likelihood(spam_score, ham_score)

        print(f"\nSpam Score: {spam_score}")
        print(f"Ham Score: {ham_score}")
        print(f"Likelihood of Spam: {likelihood}")

# %%
import re

class SpamWordsReader:
    def __init__(self, file_path):
        self.file_path = file_path
        self.spam_words = self.read_spam_keywords()

    def read_spam_keywords(self):
        with open(self.file_path, 'r') as file:
            # Using a set for faster lookups
            return set(line.strip().lower() for line in file if line.strip())

class Email:
    def __init__(self, content):
        self.content = content
        self.cleaned_content = self.preprocess_content()

    def preprocess_content(self):
        content = self.content.lower()
        # Improved regex to handle punctuation and split phrases
        content = re.sub(r'[^a-z0-9\'w\s]', ' ', content)
        return content

class SpamDetector:
    def __init__(self, spam_words):
        self.spam_words = spam_words

    def calculate_spam_score(self, email):
        normalized_email = ' ' + email + ' '  # Add spaces to match phrases at the start or end

        spam_count = 0
        for spam_word in self.spam_words:
            count = normalized_email.count(' ' + spam_word + ' ')
            spam_count += count
            # Print each spam word and the number of times it was found
            print(f"'{spam_word}' found {count} times")


        # Filtering out stop words for ham count
        stop_words = {'a', 'by', 'the', 'of', 'and', 'in', 'on', 'for', 'with',
                        'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 
                        'any', 'are', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 
                        'below', 'between', 'both', 'but', 'by', 'can', "can't", 'cannot', 'could', 
                        "couldn't", 'did', "didn't", 'do', 'does', "doesn't", 'doing', "don't", 'down', 
                        'during', 'each', 'few', 'for', 'from', 'further', 'had', "hadn't", 'has', 
                        "hasn't", 'have', "haven't", 'having', 'he', "he'd", "he'll", "he's", 'her', 
                        'here', "here's", 'hers', 'herself', 'him', 'himself', 'his', 'how', "how's", 
                        'i', "i'd", "i'll", "i'm", "i've", 'if', 'in', 'into', 'is', "isn't", 'it', 
                        "it's", 'its', 'itself', 'let', "let's", 'me', 'more', 'most', "mustn't", 'my', 
                        'myself', 'no', 'nor', 'not', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 
                        'ought', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'same', "shan't", 
                        'she', "she'd", "she'll", "she's", 'should', "shouldn't", 'so', 'some', 'such', 
                        'than', 'that', "that's", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 
                        'there', "there's", 'these', 'they', "they'd", "they'll", "they're", "they've", 
                        'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 'very', 'was', 
                        "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', "weren't", 'what', 
                        "what's", 'when', "when's", 'where', "where's", 'which', 'while', 'who', "who's", 
                        'whom', 'why', "why's", 'with', 'won', "won't", 'would', "wouldn't", 'you', 
                        "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves',
                        't'
                     }

        words = normalized_email.split()

        # Initializing ham_count
        ham_count = 0
        for word in words:
            if word not in stop_words:
                ham_count += 1
                print(f"Counting '{word}' as a ham word")  # Print each non-stop word counted as ham
            else:
                print(f"Ignoring '{word}' as it is a stop word")  # Print each stop word that is ignored

        return spam_count, ham_count


    def evaluate_spam_likelihood(self, spam_score, ham_score):
        if ham_score == 0:
            return "Unable to determine (no ham words)"
        ratio = spam_score / ham_score
        if ratio > 0.4:
            return "Highly likely to be spam"
        elif ratio > 0.2:
            return "Possibly spam"
        else:
            return "Unlikely to be spam"

if __name__ == "__main__":
    # Assuming spam_words.txt is in the same directory as this script
    spam_reader = SpamWordsReader("spam_words.txt")
    
    while True:
        email_content = input("\nEnter the email content (or type 'exit' to quit):\n")
        if email_content.lower() == 'exit':
            break

        email = Email(email_content)
        detector = SpamDetector(spam_reader.spam_words)
        spam_score, ham_score = detector.calculate_spam_score(email.cleaned_content)
        likelihood = detector.evaluate_spam_likelihood(spam_score, ham_score)

        print(f"\nSpam Score: {spam_score}")
        print(f"Ham Score: {ham_score}")
        print(f"Likelihood of Spam: {likelihood}")
# Out:
# Enter the email content (or type 'exit' to quit):
#  Dear Friend,  Are you ready to earn extra cash and achieve financial freedom? This is a once in a lifetime opportunity to be your own boss and join the ranks of those who have already earned big bucks!  🌟 100% Free, No Obligation! 🌟  With our exclusive program, you can double your income, eliminate bad credit, and enjoy risk-free investments! Here's what we offer:  Special Promotion: Sign up today and get 100% more on your first investment. Free Membership: Access our resources and community at no cost. Cash Bonus: Earn a cash bonus just for joining. No Hidden Fees: What you see is what you get. 🚀 Act Now for a Limited Time!  This isn't just any offer - it's your chance to save big money and consolidate debt. Plus, with our satisfaction guaranteed policy, you have nothing to lose.  Click Here to unlock your potential and start earning today! Remember, this incredible deal won’t last forever.  Free Gift awaits the first 100 members! Don’t miss out - apply now!
# 'unsecured credit' found 0 times
# 'no purchase necessary' found 0 times
# 'compare rates' found 0 times
# 'luxury' found 0 times
# 'cheap' found 0 times
# 'check or money order' found 0 times
# 'meet singles' found 0 times
# 'expect to earn' found 0 times
# 'mortgage rates' found 0 times
# 'pure profit' found 0 times
# 'beneficiary' found 0 times
# 'no gimmick' found 0 times
# 'earn extra cash' found 1 times
# 'this isn’t a scam' found 0 times
# 'subject to…' found 0 times
# 'deal' found 1 times
# 'click here' found 1 times
# 'no catch' found 0 times
# 'additional income' found 0 times
# 'save big money' found 1 times
# 'online marketing' found 0 times
# 'all new' found 0 times
# 'cents on the dollar' found 0 times
# 'hidden charges' found 0 times
# 'web traffic' found 0 times
# 'warranty' found 0 times
# 'miracle' found 0 times
# 'guaranteed' found 1 times
# 'take action' found 0 times
# 'information you requested' found 0 times
# 'eliminate bad credit' found 1 times
# 'social security number' found 0 times
# 'bargain' found 0 times
# 'name brand' found 0 times
# 'risk-free' found 0 times
# 'free consultation' found 0 times
# 'double your cash' found 0 times
# 'direct marketing' found 0 times
# 'quote' found 0 times
# 'free investment' found 0 times
# 'exclusive deal' found 0 times
# '100% satisfied' found 0 times
# 'extra cash' found 1 times
# 'potential earnings' found 0 times
# 'no obligation' found 1 times
# 'financial freedom' found 1 times
# 'no cost' found 1 times
# 'fast cash' found 0 times
# 'human growth hormone' found 0 times
# 'passwords' found 0 times
# 'special promotion' found 1 times
# 'sign up free' found 0 times
# 'message contains' found 0 times
# 'you have been selected' found 0 times
# 'cancel at any time' found 0 times
# 'direct email' found 0 times
# 'free membership' found 1 times
# 'billing' found 0 times
# 'new customers only' found 0 times
# 'prize' found 0 times
# 'once in a lifetime' found 1 times
# 'this won’t last' found 0 times
# 'undisclosed' found 0 times
# 'ad' found 0 times
# 'free hosting' found 0 times
# 'click below' found 0 times
# 'cures' found 0 times
# 'rates' found 0 times
# 'xanax' found 0 times
# 'pre-approved' found 0 times
# 'score' found 0 times
# 'cash bonus' found 2 times
# 'important information regarding' found 0 times
# 'this isn’t junk' found 0 times
# '100% more' found 0 times
# 'free gift' found 1 times
# 'we hate spam' found 0 times
# 'discount' found 0 times
# 'will not believe your eyes' found 0 times
# 'cards accepted' found 0 times
# 'in accordance with laws' found 0 times
# 'join millions' found 0 times
# 'free access' found 0 times
# 'free info' found 0 times
# 'clearance' found 0 times
# 'congratulations' found 0 times
# 'valium' found 0 times
# 'removal' found 0 times
# 'free quote' found 0 times
# 'refinance' found 0 times
# 'work from home' found 0 times
# 'this isn’t spam' found 0 times
# 'reserves the right' found 0 times
# 'bulk email' found 0 times
# 'free trial' found 0 times
# 'incredible deal' found 1 times
# 'requires initial investment' found 0 times
# 'promise' found 0 times
# 'weight loss' found 0 times
# 'don’t delete' found 0 times
# 'giveaway' found 0 times
# 'winner' found 0 times
# 'no fees' found 0 times
# 'you are a winner' found 0 times
# 'lose weight' found 0 times
# 'offer' found 2 times
# 'loans' found 0 times
# 'buy direct' found 0 times
# 'no hidden costs' found 0 times
# 'winning' found 0 times
# 'see for yourself' found 0 times
# 'fantastic' found 0 times
# 'best price' found 0 times
# 'be your own boss' found 1 times
# 'lifetime' found 1 times
# 'free preview' found 0 times
# 'get paid' found 0 times
# 'dear friend' found 1 times
# 'cash' found 3 times
# 'limited time' found 1 times
# 'act now' found 1 times
# 'consolidate debt' found 1 times
# 'double your income' found 1 times
# 'bonus' found 2 times
# 'call now' found 0 times
# 'apply now' found 1 times
# 'no questions asked' found 0 times
# 'one time' found 0 times
# 'while supplies last' found 0 times
# 'notspam' found 0 times
# 'become a member' found 0 times
# 'no hidden fees' found 1 times
# 'obligation' found 1 times
# 'trial' found 0 times
# 'do it today' found 0 times
# 'mass email' found 0 times
# '100% free' found 0 times
# 'internet marketing' found 0 times
# 'lowest price' found 0 times
# 'full refund' found 0 times
# 'vicodin' found 0 times
# 'money back' found 0 times
# 'billion' found 0 times
# 'extra income' found 0 times
# 'lower rates' found 0 times
# 'search engine' found 0 times
# 'satisfaction guaranteed' found 1 times
# 'unsolicited' found 0 times
# 'order now' found 0 times
# 'earn money' found 0 times
# 'accept credit cards' found 0 times
# 'as seen on' found 0 times
# 'sent in compliance' found 0 times
# 'please read' found 0 times
# 'claims' found 0 times
# 'debt' found 1 times
# 'confidentiality' found 0 times
# 'what are you waiting for?' found 0 times
# 'big bucks' found 1 times
# 'free money' found 0 times
# 'instant' found 0 times
# 'certified' found 0 times
# 'credit card offers' found 0 times
# 'get it now' found 0 times
# 'get started now' found 0 times
# 'no investment' found 0 times
# 'terms and conditions' found 0 times
# 'income' found 1 times
# 'urgent' found 0 times
# 'unlimited' found 0 times
# 'viagra' found 0 times
# 'opt in' found 0 times
# 'investment' found 1 times
# 'not junk' found 0 times
# 'marketing solution' found 0 times
# 'save up to' found 0 times
# 'multi-level marketing' found 0 times
# 'unsecured debt' found 0 times
# 'no strings attached' found 0 times
# 'no interest' found 0 times
# Counting 'dear' as a ham word
# Counting 'friend' as a ham word
# Ignoring 'are' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'ready' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'earn' as a ham word
# Counting 'extra' as a ham word
# Counting 'cash' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'achieve' as a ham word
# Counting 'financial' as a ham word
# Counting 'freedom' as a ham word
# Ignoring 'this' as it is a stop word
# Ignoring 'is' as it is a stop word
# Ignoring 'a' as it is a stop word
# Ignoring 'once' as it is a stop word
# Ignoring 'in' as it is a stop word
# Ignoring 'a' as it is a stop word
# Counting 'lifetime' as a ham word
# Counting 'opportunity' as a ham word
# Ignoring 'to' as it is a stop word
# Ignoring 'be' as it is a stop word
# Ignoring 'your' as it is a stop word
# Ignoring 'own' as it is a stop word
# Counting 'boss' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'join' as a ham word
# Ignoring 'the' as it is a stop word
# Counting 'ranks' as a ham word
# Ignoring 'of' as it is a stop word
# Ignoring 'those' as it is a stop word
# Ignoring 'who' as it is a stop word
# Ignoring 'have' as it is a stop word
# Counting 'already' as a ham word
# Counting 'earned' as a ham word
# Counting 'big' as a ham word
# Counting 'bucks' as a ham word
# Counting '100' as a ham word
# Counting 'free' as a ham word
# Ignoring 'no' as it is a stop word
# Counting 'obligation' as a ham word
# Ignoring 'with' as it is a stop word
# Ignoring 'our' as it is a stop word
# Counting 'exclusive' as a ham word
# Counting 'program' as a ham word
# Ignoring 'you' as it is a stop word
# Ignoring 'can' as it is a stop word
# Counting 'double' as a ham word
# Ignoring 'your' as it is a stop word
# Counting 'income' as a ham word
# Counting 'eliminate' as a ham word
# Counting 'bad' as a ham word
# Counting 'credit' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'enjoy' as a ham word
# Counting 'risk' as a ham word
# Counting 'free' as a ham word
# Counting 'investments' as a ham word
# Ignoring 'here's' as it is a stop word
# Ignoring 'what' as it is a stop word
# Ignoring 'we' as it is a stop word
# Counting 'offer' as a ham word
# Counting 'special' as a ham word
# Counting 'promotion' as a ham word
# Counting 'sign' as a ham word
# Ignoring 'up' as it is a stop word
# Counting 'today' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'get' as a ham word
# Counting '100' as a ham word
# Ignoring 'more' as it is a stop word
# Ignoring 'on' as it is a stop word
# Ignoring 'your' as it is a stop word
# Counting 'first' as a ham word
# Counting 'investment' as a ham word
# Counting 'free' as a ham word
# Counting 'membership' as a ham word
# Counting 'access' as a ham word
# Ignoring 'our' as it is a stop word
# Counting 'resources' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'community' as a ham word
# Ignoring 'at' as it is a stop word
# Ignoring 'no' as it is a stop word
# Counting 'cost' as a ham word
# Counting 'cash' as a ham word
# Counting 'bonus' as a ham word
# Counting 'earn' as a ham word
# Ignoring 'a' as it is a stop word
# Counting 'cash' as a ham word
# Counting 'bonus' as a ham word
# Counting 'just' as a ham word
# Ignoring 'for' as it is a stop word
# Counting 'joining' as a ham word
# Ignoring 'no' as it is a stop word
# Counting 'hidden' as a ham word
# Counting 'fees' as a ham word
# Ignoring 'what' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'see' as a ham word
# Ignoring 'is' as it is a stop word
# Ignoring 'what' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'get' as a ham word
# Counting 'act' as a ham word
# Counting 'now' as a ham word
# Ignoring 'for' as it is a stop word
# Ignoring 'a' as it is a stop word
# Counting 'limited' as a ham word
# Counting 'time' as a ham word
# Ignoring 'this' as it is a stop word
# Ignoring 'isn't' as it is a stop word
# Counting 'just' as a ham word
# Ignoring 'any' as it is a stop word
# Counting 'offer' as a ham word
# Ignoring 'it's' as it is a stop word
# Ignoring 'your' as it is a stop word
# Counting 'chance' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'save' as a ham word
# Counting 'big' as a ham word
# Counting 'money' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'consolidate' as a ham word
# Counting 'debt' as a ham word
# Counting 'plus' as a ham word
# Ignoring 'with' as it is a stop word
# Ignoring 'our' as it is a stop word
# Counting 'satisfaction' as a ham word
# Counting 'guaranteed' as a ham word
# Counting 'policy' as a ham word
# Ignoring 'you' as it is a stop word
# Ignoring 'have' as it is a stop word
# Counting 'nothing' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'lose' as a ham word
# Counting 'click' as a ham word
# Ignoring 'here' as it is a stop word
# Ignoring 'to' as it is a stop word
# Counting 'unlock' as a ham word
# Ignoring 'your' as it is a stop word
# Counting 'potential' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'start' as a ham word
# Counting 'earning' as a ham word
# Counting 'today' as a ham word
# Counting 'remember' as a ham word
# Ignoring 'this' as it is a stop word
# Counting 'incredible' as a ham word
# Counting 'deal' as a ham word
# Ignoring 'won' as it is a stop word
# Ignoring 't' as it is a stop word
# Counting 'last' as a ham word
# Counting 'forever' as a ham word
# Counting 'free' as a ham word
# Counting 'gift' as a ham word
# Counting 'awaits' as a ham word
# Ignoring 'the' as it is a stop word
# Counting 'first' as a ham word
# Counting '100' as a ham word
# Counting 'members' as a ham word
# Counting 'don' as a ham word
# Ignoring 't' as it is a stop word
# Counting 'miss' as a ham word
# Ignoring 'out' as it is a stop word
# Counting 'apply' as a ham word
# Counting 'now' as a ham word
#
# Spam Score: 39
# Ham Score: 97
# Likelihood of Spam: Highly likely to be spam
# Enter the email content (or type 'exit' to quit):
#  exit

# %%
import re

class SpamWordsReader:
    def __init__(self, file_path):
        self.file_path = file_path
        self.spam_words = self.read_spam_keywords()

    def read_spam_keywords(self):
        with open(self.file_path, 'r') as file:
            # Using a set for faster lookups
            return set(line.strip().lower() for line in file if line.strip())

class Email:
    def __init__(self, content):
        self.content = content
        self.cleaned_content = self.preprocess_content()

    def preprocess_content(self):
        content = self.content.lower()
        # Improved regex to handle punctuation and split phrases
        content = re.sub(r'[^a-z0-9\'w\s]', ' ', content)
        return content

class SpamDetector:
    def __init__(self, spam_words):
        self.spam_words = spam_words

    def calculate_spam_score(self, email):
        normalized_email = ' ' + email + ' '  # Add spaces to match phrases at the start or end

        spam_count = 0
        for spam_word in self.spam_words:
            count = normalized_email.count(' ' + spam_word + ' ')
            spam_count += count
            # Print each spam word and the number of times it was found
            print(f"'{spam_word}' found {count} times")


        # Filtering out stop words for ham count
        stop_words = {'a', 'by', 'the', 'of', 'and', 'in', 'on', 'for', 'with',
                        'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 
                        'any', 'are', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 
                        'below', 'between', 'both', 'but', 'by', 'can', "can't", 'cannot', 'could', 
                        "couldn't", 'did', "didn't", 'do', 'does', "doesn't", 'doing', "don't", 'down', 
                        'during', 'each', 'few', 'for', 'from', 'further', 'had', "hadn't", 'has', 
                        "hasn't", 'have', "haven't", 'having', 'he', "he'd", "he'll", "he's", 'her', 
                        'here', "here's", 'hers', 'herself', 'him', 'himself', 'his', 'how', "how's", 
                        'i', "i'd", "i'll", "i'm", "i've", 'if', 'in', 'into', 'is', "isn't", 'it', 
                        "it's", 'its', 'itself', 'let', "let's", 'me', 'more', 'most', "mustn't", 'my', 
                        'myself', 'no', 'nor', 'not', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 
                        'ought', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'same', "shan't", 
                        'she', "she'd", "she'll", "she's", 'should', "shouldn't", 'so', 'some', 'such', 
                        'than', 'that', "that's", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 
                        'there', "there's", 'these', 'they', "they'd", "they'll", "they're", "they've", 
                        'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 'very', 'was', 
                        "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', "weren't", 'what', 
                        "what's", 'when', "when's", 'where', "where's", 'which', 'while', 'who', "who's", 
                        'whom', 'why', "why's", 'with', 'won', "won't", 'would', "wouldn't", 'you', 
                        "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves',
                        't'
                     }

        words = normalized_email.split()

        # Initializing ham_count
        ham_count = 0
        for word in words:
            if word not in stop_words:
                ham_count += 1
                print(f"Counting '{word}' as a ham word")  # Print each non-stop word counted as ham
            else:
                print(f"Ignoring '{word}' as it is a stop word")  # Print each stop word that is ignored

        return spam_count, ham_count


    def evaluate_spam_likelihood(self, spam_score, ham_score):
        if ham_score == 0:
            return "Unable to determine (no ham words)"
        ratio = spam_score / ham_score
        if ratio > 0.4:
            return "Highly likely to be spam"
        elif ratio > 0.2:
            return "Possibly spam"
        else:
            return "Unlikely to be spam"

if __name__ == "__main__":
    # Assuming spam_words.txt is in the same directory as this script
    spam_reader = SpamWordsReader("spam_words.txt")
    
    while True:
        email_content = input("\nEnter the email content (or type 'exit' to quit):\n")
        if email_content.lower() == 'exit':
            break

        email = Email(email_content)
        detector = SpamDetector(spam_reader.spam_words)
        spam_score, ham_score = detector.calculate_spam_score(email.cleaned_content)
        likelihood = detector.evaluate_spam_likelihood(spam_score, ham_score)

        print(f"\nSpam Score: {spam_score}")
        print(f"Ham Score: {ham_score}")
        print(f"Likelihood of Spam: {likelihood}")
# Out:
# Enter the email content (or type 'exit' to quit):
#  Dear Friend,  Are you ready to earn extra cash and achieve financial freedom? This is a once in a lifetime opportunity to be your own boss and join the ranks of those who have already earned big bucks!  🌟 100% Free, No Obligation! 🌟  With our exclusive program, you can double your income, eliminate bad credit, and enjoy risk-free investments! Here's what we offer:  Special Promotion: Sign up today and get 100% more on your first investment. Free Membership: Access our resources and community at no cost. Cash Bonus: Earn a cash bonus just for joining. No Hidden Fees: What you see is what you get. 🚀 Act Now for a Limited Time!  This isn't just any offer - it's your chance to save big money and consolidate debt. Plus, with our satisfaction guaranteed policy, you have nothing to lose.  Click Here to unlock your potential and start earning today! Remember, this incredible deal won’t last forever.  Free Gift awaits the first 100 members! Don’t miss out - apply now!
# 'unsecured credit' found 0 times
# 'no purchase necessary' found 0 times
# 'compare rates' found 0 times
# 'luxury' found 0 times
# 'cheap' found 0 times
# 'check or money order' found 0 times
# 'meet singles' found 0 times
# 'expect to earn' found 0 times
# 'mortgage rates' found 0 times
# 'pure profit' found 0 times
# 'beneficiary' found 0 times
# 'no gimmick' found 0 times
# 'earn extra cash' found 1 times
# 'this isn’t a scam' found 0 times
# 'subject to…' found 0 times
# 'deal' found 1 times
# 'click here' found 1 times
# 'no catch' found 0 times
# 'additional income' found 0 times
# 'save big money' found 1 times
# 'online marketing' found 0 times
# 'all new' found 0 times
# 'cents on the dollar' found 0 times
# 'hidden charges' found 0 times
# 'web traffic' found 0 times
# 'warranty' found 0 times
# 'miracle' found 0 times
# 'guaranteed' found 1 times
# 'take action' found 0 times
# 'information you requested' found 0 times
# 'eliminate bad credit' found 1 times
# 'social security number' found 0 times
# 'bargain' found 0 times
# 'name brand' found 0 times
# 'risk-free' found 0 times
# 'free consultation' found 0 times
# 'double your cash' found 0 times
# 'direct marketing' found 0 times
# 'quote' found 0 times
# 'free investment' found 0 times
# 'exclusive deal' found 0 times
# '100% satisfied' found 0 times
# 'extra cash' found 1 times
# 'potential earnings' found 0 times
# 'no obligation' found 1 times
# 'financial freedom' found 1 times
# 'no cost' found 1 times
# 'fast cash' found 0 times
# 'human growth hormone' found 0 times
# 'passwords' found 0 times
# 'special promotion' found 1 times
# 'sign up free' found 0 times
# 'message contains' found 0 times
# 'you have been selected' found 0 times
# 'cancel at any time' found 0 times
# 'direct email' found 0 times
# 'free membership' found 1 times
# 'billing' found 0 times
# 'new customers only' found 0 times
# 'prize' found 0 times
# 'once in a lifetime' found 1 times
# 'this won’t last' found 0 times
# 'undisclosed' found 0 times
# 'ad' found 0 times
# 'free hosting' found 0 times
# 'click below' found 0 times
# 'cures' found 0 times
# 'rates' found 0 times
# 'xanax' found 0 times
# 'pre-approved' found 0 times
# 'score' found 0 times
# 'cash bonus' found 2 times
# 'important information regarding' found 0 times
# 'this isn’t junk' found 0 times
# '100% more' found 0 times
# 'free gift' found 1 times
# 'we hate spam' found 0 times
# 'discount' found 0 times
# 'will not believe your eyes' found 0 times
# 'cards accepted' found 0 times
# 'in accordance with laws' found 0 times
# 'join millions' found 0 times
# 'free access' found 0 times
# 'free info' found 0 times
# 'clearance' found 0 times
# 'congratulations' found 0 times
# 'valium' found 0 times
# 'removal' found 0 times
# 'free quote' found 0 times
# 'refinance' found 0 times
# 'work from home' found 0 times
# 'this isn’t spam' found 0 times
# 'reserves the right' found 0 times
# 'bulk email' found 0 times
# 'free trial' found 0 times
# 'incredible deal' found 1 times
# 'requires initial investment' found 0 times
# 'promise' found 0 times
# 'weight loss' found 0 times
# 'don’t delete' found 0 times
# 'giveaway' found 0 times
# 'winner' found 0 times
# 'no fees' found 0 times
# 'you are a winner' found 0 times
# 'lose weight' found 0 times
# 'offer' found 2 times
# 'loans' found 0 times
# 'buy direct' found 0 times
# 'no hidden costs' found 0 times
# 'winning' found 0 times
# 'see for yourself' found 0 times
# 'fantastic' found 0 times
# 'best price' found 0 times
# 'be your own boss' found 1 times
# 'lifetime' found 1 times
# 'free preview' found 0 times
# 'get paid' found 0 times
# 'dear friend' found 1 times
# 'cash' found 3 times
# 'limited time' found 1 times
# 'act now' found 1 times
# 'consolidate debt' found 1 times
# 'double your income' found 1 times
# 'bonus' found 2 times
# 'call now' found 0 times
# 'apply now' found 1 times
# 'no questions asked' found 0 times
# 'one time' found 0 times
# 'while supplies last' found 0 times
# 'notspam' found 0 times
# 'become a member' found 0 times
# 'no hidden fees' found 1 times
# 'obligation' found 1 times
# 'trial' found 0 times
# 'do it today' found 0 times
# 'mass email' found 0 times
# '100% free' found 0 times
# 'internet marketing' found 0 times
# 'lowest price' found 0 times
# 'full refund' found 0 times
# 'vicodin' found 0 times
# 'money back' found 0 times
# 'billion' found 0 times
# 'extra income' found 0 times
# 'lower rates' found 0 times
# 'search engine' found 0 times
# 'satisfaction guaranteed' found 1 times
# 'unsolicited' found 0 times
# 'order now' found 0 times
# 'earn money' found 0 times
# 'accept credit cards' found 0 times
# 'as seen on' found 0 times
# 'sent in compliance' found 0 times
# 'please read' found 0 times
# 'claims' found 0 times
# 'debt' found 1 times
# 'confidentiality' found 0 times
# 'what are you waiting for?' found 0 times
# 'big bucks' found 1 times
# 'free money' found 0 times
# 'instant' found 0 times
# 'certified' found 0 times
# 'credit card offers' found 0 times
# 'get it now' found 0 times
# 'get started now' found 0 times
# 'no investment' found 0 times
# 'terms and conditions' found 0 times
# 'income' found 1 times
# 'urgent' found 0 times
# 'unlimited' found 0 times
# 'viagra' found 0 times
# 'opt in' found 0 times
# 'investment' found 1 times
# 'not junk' found 0 times
# 'marketing solution' found 0 times
# 'save up to' found 0 times
# 'multi-level marketing' found 0 times
# 'unsecured debt' found 0 times
# 'no strings attached' found 0 times
# 'no interest' found 0 times
# Counting 'dear' as a ham word
# Counting 'friend' as a ham word
# Ignoring 'are' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'ready' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'earn' as a ham word
# Counting 'extra' as a ham word
# Counting 'cash' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'achieve' as a ham word
# Counting 'financial' as a ham word
# Counting 'freedom' as a ham word
# Ignoring 'this' as it is a stop word
# Ignoring 'is' as it is a stop word
# Ignoring 'a' as it is a stop word
# Ignoring 'once' as it is a stop word
# Ignoring 'in' as it is a stop word
# Ignoring 'a' as it is a stop word
# Counting 'lifetime' as a ham word
# Counting 'opportunity' as a ham word
# Ignoring 'to' as it is a stop word
# Ignoring 'be' as it is a stop word
# Ignoring 'your' as it is a stop word
# Ignoring 'own' as it is a stop word
# Counting 'boss' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'join' as a ham word
# Ignoring 'the' as it is a stop word
# Counting 'ranks' as a ham word
# Ignoring 'of' as it is a stop word
# Ignoring 'those' as it is a stop word
# Ignoring 'who' as it is a stop word
# Ignoring 'have' as it is a stop word
# Counting 'already' as a ham word
# Counting 'earned' as a ham word
# Counting 'big' as a ham word
# Counting 'bucks' as a ham word
# Counting '100' as a ham word
# Counting 'free' as a ham word
# Ignoring 'no' as it is a stop word
# Counting 'obligation' as a ham word
# Ignoring 'with' as it is a stop word
# Ignoring 'our' as it is a stop word
# Counting 'exclusive' as a ham word
# Counting 'program' as a ham word
# Ignoring 'you' as it is a stop word
# Ignoring 'can' as it is a stop word
# Counting 'double' as a ham word
# Ignoring 'your' as it is a stop word
# Counting 'income' as a ham word
# Counting 'eliminate' as a ham word
# Counting 'bad' as a ham word
# Counting 'credit' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'enjoy' as a ham word
# Counting 'risk' as a ham word
# Counting 'free' as a ham word
# Counting 'investments' as a ham word
# Ignoring 'here's' as it is a stop word
# Ignoring 'what' as it is a stop word
# Ignoring 'we' as it is a stop word
# Counting 'offer' as a ham word
# Counting 'special' as a ham word
# Counting 'promotion' as a ham word
# Counting 'sign' as a ham word
# Ignoring 'up' as it is a stop word
# Counting 'today' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'get' as a ham word
# Counting '100' as a ham word
# Ignoring 'more' as it is a stop word
# Ignoring 'on' as it is a stop word
# Ignoring 'your' as it is a stop word
# Counting 'first' as a ham word
# Counting 'investment' as a ham word
# Counting 'free' as a ham word
# Counting 'membership' as a ham word
# Counting 'access' as a ham word
# Ignoring 'our' as it is a stop word
# Counting 'resources' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'community' as a ham word
# Ignoring 'at' as it is a stop word
# Ignoring 'no' as it is a stop word
# Counting 'cost' as a ham word
# Counting 'cash' as a ham word
# Counting 'bonus' as a ham word
# Counting 'earn' as a ham word
# Ignoring 'a' as it is a stop word
# Counting 'cash' as a ham word
# Counting 'bonus' as a ham word
# Counting 'just' as a ham word
# Ignoring 'for' as it is a stop word
# Counting 'joining' as a ham word
# Ignoring 'no' as it is a stop word
# Counting 'hidden' as a ham word
# Counting 'fees' as a ham word
# Ignoring 'what' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'see' as a ham word
# Ignoring 'is' as it is a stop word
# Ignoring 'what' as it is a stop word
# Ignoring 'you' as it is a stop word
# Counting 'get' as a ham word
# Counting 'act' as a ham word
# Counting 'now' as a ham word
# Ignoring 'for' as it is a stop word
# Ignoring 'a' as it is a stop word
# Counting 'limited' as a ham word
# Counting 'time' as a ham word
# Ignoring 'this' as it is a stop word
# Ignoring 'isn't' as it is a stop word
# Counting 'just' as a ham word
# Ignoring 'any' as it is a stop word
# Counting 'offer' as a ham word
# Ignoring 'it's' as it is a stop word
# Ignoring 'your' as it is a stop word
# Counting 'chance' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'save' as a ham word
# Counting 'big' as a ham word
# Counting 'money' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'consolidate' as a ham word
# Counting 'debt' as a ham word
# Counting 'plus' as a ham word
# Ignoring 'with' as it is a stop word
# Ignoring 'our' as it is a stop word
# Counting 'satisfaction' as a ham word
# Counting 'guaranteed' as a ham word
# Counting 'policy' as a ham word
# Ignoring 'you' as it is a stop word
# Ignoring 'have' as it is a stop word
# Counting 'nothing' as a ham word
# Ignoring 'to' as it is a stop word
# Counting 'lose' as a ham word
# Counting 'click' as a ham word
# Ignoring 'here' as it is a stop word
# Ignoring 'to' as it is a stop word
# Counting 'unlock' as a ham word
# Ignoring 'your' as it is a stop word
# Counting 'potential' as a ham word
# Ignoring 'and' as it is a stop word
# Counting 'start' as a ham word
# Counting 'earning' as a ham word
# Counting 'today' as a ham word
# Counting 'remember' as a ham word
# Ignoring 'this' as it is a stop word
# Counting 'incredible' as a ham word
# Counting 'deal' as a ham word
# Ignoring 'won' as it is a stop word
# Ignoring 't' as it is a stop word
# Counting 'last' as a ham word
# Counting 'forever' as a ham word
# Counting 'free' as a ham word
# Counting 'gift' as a ham word
# Counting 'awaits' as a ham word
# Ignoring 'the' as it is a stop word
# Counting 'first' as a ham word
# Counting '100' as a ham word
# Counting 'members' as a ham word
# Counting 'don' as a ham word
# Ignoring 't' as it is a stop word
# Counting 'miss' as a ham word
# Ignoring 'out' as it is a stop word
# Counting 'apply' as a ham word
# Counting 'now' as a ham word
#
# Spam Score: 39
# Ham Score: 97
# Likelihood of Spam: Highly likely to be spam
# Enter the email content (or type 'exit' to quit):
#  exit

# %% [markdown]
# Urgent! \nPlease verify your bank account by
#     clicking the link: ACTION REQUIRED. Please verify your
#     Bank of America account information to avoid a hold on
#     your account. Click here to confirm: [Link]

# %% [markdown]
# Dear Friend,
#
# Are you ready to earn extra cash and achieve financial freedom? This is a once in a lifetime opportunity to be your own boss and join the ranks of those who have already earned big bucks!
#
# 🌟 100% Free, No Obligation! 🌟
#
# With our exclusive program, you can double your income, eliminate bad credit, and enjoy risk-free investments! Here's what we offer:
#
# Special Promotion: Sign up today and get 100% more on your first investment.
# Free Membership: Access our resources and community at no cost.
# Cash Bonus: Earn a cash bonus just for joining.
# No Hidden Fees: What you see is what you get.
# 🚀 Act Now for a Limited Time!
#
# This isn't just any offer - it's your chance to save big money and consolidate debt. Plus, with our satisfaction guaranteed policy, you have nothing to lose.
#
# Click Here to unlock your potential and start earning today! Remember, this incredible deal won’t last forever.
#
# Free Gift awaits the first 100 members! Don’t miss out - apply now!
